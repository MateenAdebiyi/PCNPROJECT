# %%
for lamda in range(11):
    #print (lamda)
    theta1=0.5*(lamda+1)
    theta2=2.25*(lamda+1)
    theta3=2.5*(lamda+1)
    mew1=6
    mew2=25
    mew3=30
    print ('throughput1 :'+str(theta1))
    print ('util1 :'+str(theta1/mew1))
    k= theta1/mew1
    r=k/(1-k)
    print ('Expected1 :'+str(r))
    print ('ET1 :'+str(r/theta1))
    print("---------------------------")
    print ('throughput2 :'+str(theta2))
    print ('util2 :'+str(theta2/mew2))
    k1= theta2/mew2
    r1=k1/(1-k1)
    print ('Expected2 :'+str(r1))
    print ('ET2 :'+str(r1/theta2))
    print("---------------------------")
    print ('throughput3 :'+str(theta3))
    print ('util3 :'+str(theta3/mew3))
    k2= theta3/mew3
    r2=k2/(1-k2)
    print ('Expected2 :'+str(r2))
    print ('ET1 :'+str(r2/theta3))
    print("---------------------------")
# Out:
# throughput1 :0.5
# util1 :0.08333333333333333
# Expected1 :0.09090909090909091
# ET1 :0.18181818181818182
# ---------------------------
# throughput2 :2.25
# util2 :0.09
# Expected2 :0.0989010989010989
# ET2 :0.04395604395604395
# ---------------------------
# throughput3 :2.5
# util3 :0.08333333333333333
# Expected2 :0.09090909090909091
# ET1 :0.03636363636363636
# ---------------------------
# throughput1 :1.0
# util1 :0.16666666666666666
# Expected1 :0.19999999999999998
# ET1 :0.19999999999999998
# ---------------------------
# throughput2 :4.5
# util2 :0.18
# Expected2 :0.2195121951219512
# ET2 :0.048780487804878044
# ---------------------------
# throughput3 :5.0
# util3 :0.16666666666666666
# Expected2 :0.19999999999999998
# ET1 :0.039999999999999994
# ---------------------------
# throughput1 :1.5
# util1 :0.25
# Expected1 :0.3333333333333333
# ET1 :0.2222222222222222
# ---------------------------
# throughput2 :6.75
# util2 :0.27
# Expected2 :0.36986301369863017
# ...

# %%
print ('I am a boy')
# Out:
# I am a boy
